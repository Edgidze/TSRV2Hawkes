# %%
from utils import *

basicConfig(filename = '_Preprocessing.log', level = INFO)


def get_signed_volume(df):
    tmp = copy(df)

    tmp['Bid Price'] = tmp['Bid Price'].ffill()
    tmp['Ask Price'] = tmp['Ask Price'].ffill()

    trades = tmp[tmp['Type'].isin(['Trade'])]
    trades['Mid Price']     = (trades['Bid Price'] + trades['Ask Price']) / 2
    trades['buy_sell_ind']  = np.where(trades['Price'] > trades['Mid Price'],1,-1)
    trades['signed Volume'] = trades['Volume'] * trades['buy_sell_ind']
    
    return trades.set_index('t')['signed Volume']


def extract(df):
    """Extract only the necessary information"""

    trade  = df[df['Type'].isin(['Trade'])].set_index('t')[['Price','Volume']]
    trade['Signed Volume'] = get_signed_volume(df)
    assert np.array_equal(trade['Volume'], np.abs(trade['Signed Volume']),
                          equal_nan=True)
    quote  = df[~df['Type'].isin(['Trade'])].set_index('t')[['Bid Price','Ask Price']]

    return {'trade': trade, 'quote': quote}

# %% [markdown]
# ## Data Converting
#
# Since `csv` file size exceeds the memory of the sever, we have to read chunk by chunks.

# %%
# %%time
now_time  = 1999.5
CHUNKSIZE = 500000

PATH_TO_CSV_ARCHIVES = 'data/E-mini_TickDataMarket'

for now_time in np.arange(2020.25, 2022.75, .25):
    print(str(now_time), end=':')
    
    t1 = time()
    extrs = {}
    df0 = pd.DataFrame()
    for df in pd.read_csv(
        # 'data/E-mini_TickDataMarket/ES%s.csv'%get_futures_code(now_time),
        #                   chunksize=CHUNKSIZE):
        # results saving
        PATH_TO_CSV_ARCHIVES + '/ES%s.csv'%get_futures_code(now_time),
                          chunksize=CHUNKSIZE):
        df0 = pd.concat([df0,df])
        dates = pd.to_datetime(pd.unique(df['Date'])).sort_values()
        if len(dates) > 1:
            dates = pd.to_datetime(pd.unique(df0['Date'])).sort_values()
            if len(df) < CHUNKSIZE:
                df_now = df0
            else:
                df_now = df0[df0['Date'].isin(dates[:-1].strftime("%m/%d/%Y"))]
            df_now['t'] = pd.to_timedelta(df_now['Time']).dt.total_seconds()
            extr        = dict([(k,extract(v)) for k,v in df_now.groupby('Date')])
            extrs.update(extr)
            df0 = copy(df[df['Date']==dates[-1].strftime("%m/%d/%Y")])
            
    # results saving
    joblib.dump(extrs, 'save/E-mini/ES%s.dat'%get_futures_code(now_time))
    
    t2 = time()
    print('%.3f sec'%(t2 - t1))
    info(str(now_time) + ': %.3f sec'%(t2 - t1))
# Out:
# 2022.25:2052.533 sec
# 2022.5:698.347 sec
# CPU times: total: 43min 38s
# Wall time: 45min 51s

# %% [markdown]
# ## Calculations for days

# %%
from utils import *
from main  import *
from other import *

basicConfig(filename = 'Empirics.log', level = INFO)

# %%
START =  8.5*3600 + 15 * 60
END   = 15.0*3600 - 15 * 60
def filter_time(t, unit='s',
                start=START, end=END):
    """Filter regular trading hour (8:30 a.m. – 3:00 p.m.)
    
    For discarding open and close large trading, we remove first and last 15 
    minutes.
    
    References
    ----------
    .. [1] https://www.cmegroup.com/education/files/eq-trading-hours.pdf
    """
    if unit == 's':
        return t[(t >= start) & (t <= end)]
    if unit == 'm':
        return t[(t >= start/60) & (t <= end/60)]
    else:
        raise NotImplementedError("unit %s is not implemented yet."%unit)


def get_min_value(x, interval=1, start=START, end=END):
    min_ranges = pd.Series(index=np.arange(int(start/60), 
                                           int(end  /60) + interval,
                                           interval),
                           name=x.index.name)
    last = x.groupby(level=0).last()
    out  = pd.merge(min_ranges, last, how='left', 
                    left_index=True, right_index=True)
    out  = out[x.name]
    
    return out.ffill().bfill()


def get_redist(data, min_offset=.001):
    """For the same time points, randomly distribute them."""
    if isinstance(data, pd.DataFrame):
        tmp = data
    else:
        tmp = pd.DataFrame({'t':data})
        
    flag_dup = (tmp.groupby('t')['t'].count() > 1)    
    if flag_dup.sum() == 0:
        tmp['t_redist'] = tmp['t']
        if isinstance(data, pd.DataFrame):
            return tmp
        return tmp['t_redist']
    if len(flag_dup) == 1:
        tmp['t_redist'] = tmp['t']\
                            + np.sort(np.random.uniform(-min_offset * len(tmp),
                                                         min_offset * len(tmp),
                                                        size = len(tmp)))
        if isinstance(data, pd.DataFrame):
            return tmp
        return tmp['t_redist']
    
    flag_dup.name = '1_dup'
    flag_dup = flag_dup.sort_index()
    flag_dup = flag_dup.reset_index()
    flag_dup['st'] = (flag_dup['t'] + flag_dup['t'].shift(1)) / 2
    flag_dup['en'] = (flag_dup['t'] + flag_dup['t'].shift(-1)) / 2
    offset = min(np.nan_to_num(
        flag_dup['st'].iloc[:min(5,len(data))].diff().mean(), nan=1),
                 min_offset)
    flag_dup['st'] = flag_dup['st'].fillna(flag_dup['st'].iloc[1] - offset)
    offset = min(np.nan_to_num(
        flag_dup['en'].iloc[-min(5,len(data)):].diff().mean(), nan=1),
                 min_offset)
    flag_dup['en'] = flag_dup['en'].fillna(flag_dup['en'].iloc[-2] + offset)
    tmp = pd.merge(tmp, flag_dup.reset_index(), how='left', on='t')
    tmp['t_redist'] = (np.random.uniform(size=len(tmp)) * (tmp['en'] - tmp['st'])\
                       + tmp['st'])*tmp['1_dup'] + tmp['t'] * (~tmp['1_dup'])
    
    if isinstance(data, pd.DataFrame):
        return tmp.sort_values('t_redist')
    
    return np.sort(tmp['t_redist'])


def get_VPIN(trade):
    n = 50
    V = trade['Volume'].sum() / n
    if V <= 1:
        return np.nan

    trade['V_i'] = trade['Volume'].cumsum() // V
    VPIN = trade.groupby('V_i')['Signed Volume'].sum().abs().sum() \
            / trade['Volume'].sum()
    
    return VPIN


def estimate_Hawkes(points):
    t1 = time()
    ress = {}
    for estimator in estimators:
        ress[estimator.__name__] = estimator(points)
    if VERBOSE:
        print("\t %.3f sec"%(time() - t1))
        
    return ress


def estimate(date, seed=1):
    np.random.seed(seed)
    
    dat = data[date]
    
    out = {}
    trade = dat['trade']
    quote = dat['quote']
    quote['Bid Price'] = quote['Bid Price'].ffill().bfill()
    quote['Ask Price'] = quote['Ask Price'].ffill().bfill()
    quote['Mid Price'] = (quote['Bid Price'] + quote['Ask Price']) / 2
    
    # Summary stats
    out['price(init)'] = trade['Price'][~np.isnan(trade['Price'])].iloc[0]
    out['price(high)'] = np.nanmax(trade['Price'])
    out['price(low)' ] = np.nanmin(trade['Price'])
    out['price(last)'] = trade['Price'][~np.isnan(trade['Price'])].iloc[-1]
    out['price(mean)'] = np.nanmean(trade['Price'])
    out['price(std)' ] = np.nanstd(trade['Price'])
    
    # Liquidity measure
    out['volume'] = np.nansum(trade['Volume'])
    out['dollar_volume'] = np.nansum(trade['Price'] * trade['Volume'])
    out['VPIN'] = get_VPIN(trade[(START <= trade.index) & (trade.index <= END)])
    
    # RV caluclation
    trade['min'] = (trade.index // 60).astype(int)
    price_1min = get_min_value(trade.set_index('min')['Price'], interval=1)
    price_5min = get_min_value(trade.set_index('min')['Price'], interval=5)
    out['RV(1min)'] = RVEstimator(np.log(price_1min))
    out['RV(5min)'] = RVEstimator(np.log(price_5min))
    
    # Hawkes estimation
    mid_mask = (quote['Mid Price'] - quote['Mid Price'].shift(1)).fillna(1) != 0
    
    trade_points = to_0_1(filter_time(get_redist(trade.index)))
    quote_points = to_0_1(filter_time(get_redist(quote.index)))
    mid_points   = to_0_1(filter_time(get_redist(quote[mid_mask].index)))
    
    out['trade']      = estimate_Hawkes(trade_points)
    out['quote']      = estimate_Hawkes(quote_points)
    out['mid_change'] = estimate_Hawkes(mid_points)
    
    del price_1min, price_5min, trade, quote, mid_mask
    del trade_points, quote_points, mid_points
    gc.collect()

    return out


def log_out(i, out):
    pool_out[i] = out

# %%
POTENTIAL_EXCEPTIONS_FILE_PATH = "C:/YOUR_WAY_YO_FILE_WITH_EXCEPTIONS/Exceptions.txt"

# new code for functionalyty check
import traceback

# %% [markdown]
# ## Estimation
#
# For each day, determine futures product based on volume.
# After that, estimate some statistics for that futures data.
#
#     ESH2019        ▼ Maturity of ESH2019
#  └─────────────┴─────────┐
#
#         BUFFER ┖──┚    ESM2019  ▲ Maturity of ESM2019
#
#                 ▲ Choose the next date using volume within this BUFFER

# %%
BUFFER  = 14
MIN_NUM = 100
VERBOSE = True


now_quarter = 2020.25

prev_date   = pd.to_datetime("09/09/1999", format='%m/%d/%Y')
next_date   = pd.to_datetime("09/09/2199", format='%m/%d/%Y')


estimators = [BR_estimation, Hardiman, AVG_Hardiman_4, AVG_Hardiman_30min,
              AVG_Hardiman_5min, Exp_estimation, EM_estimation,
             ]


stop = False
while now_quarter < 2022.5 or stop:
    t1 = time()
    
    # Load data
    data   = joblib.load('save/E-mini/ES%s.dat'\
                         # %get_futures_code(now_quarter))
    dates  = np.array(pd.to_datetime(list(data.keys()), format='%m/%d/%Y')\
                      .sort_values().strftime('%m/%d/%Y').to_list())
    daily_volume = pd.Series([np.nansum(data[date]['trade']['Volume'])
                              for date in dates], 
                             index=pd.to_datetime(dates))

    # Filtering
    bdates    = pd.bdate_range(prev_date, next_date).strftime('%m/%d/%Y')
    liq_dates = np.array([date for date in dates \
                          if len(data[date]['trade']) > MIN_NUM])
    flt_dates = intersect(dates, bdates, liq_dates)
    
    # Estimation
    pool_out = {}

    # modified algorithm
    try:
        print("The dates are: " + str(flt_dates))
        print("There are " + str(len(flt_dates)))


        for date in flt_dates:
            print("Current date is " + str(date))
            
            if date not in pool_out:
                # step by step version
                pool_out[date] = estimate(date)
    except KeyboardInterrupt:
        print('INTERRUPTED')
    pool_out = dict(sorted(pool_out.items()))
    
    # Choose a next date: A date choosing the next futures product.
    try:
        data2  = joblib.load('save/E-mini/ES%s.dat'\
                             # %get_futures_code(now_quarter + .25))
        dates2 = np.array(pd.to_datetime(list(data2.keys()), format='%m/%d/%Y')\
                          .sort_values().strftime('%m/%d/%Y').to_list())
        daily_volume2 = pd.Series([np.nansum(data2[date]['trade']['Volume'])
                                   for date in dates2], 
                                  index=pd.to_datetime(dates2))
    
        next_date = daily_volume.index[-1]  # initialize with the last date.
        for date, vol in daily_volume[-BUFFER:].iteritems():
            if vol < daily_volume2[date]:
                next_date = date
                break
    except Exception as e:
        with open(POTENTIAL_EXCEPTIONS_FILE_PATH, "a") as f:
            f.write(str(e))
            f.write(traceback.format_exc())
        stop = True
    
    out_dates = np.array(list(pool_out.keys()))
    for date in out_dates[pd.to_datetime(out_dates) > pd.to_datetime(next_date)]:
        del pool_out[date]
    joblib.dump(pool_out, 'save/emp/%.2f.dat'%now_quarter)

    msg = str(now_quarter) + '\t' + next_date.strftime('%m/%d/%Y')\
          + '  (%5.3f s)'%(time()-t1)
    print(msg); info(msg)
    
    # Go to next step
    prev_date    = next_date + pd.to_timedelta(1, unit='d')
    next_date   += pd.to_timedelta(999, unit='d')
    now_quarter += 0.25
# Out:
# The dates are: ['09/15/2021' '06/18/2021' '09/10/2021' '09/08/2021' '09/03/2021'
#  '07/14/2021' '02/25/2021' '03/22/2021' '06/28/2021' '07/19/2021'
#  '03/03/2021' '05/12/2021' '07/27/2021' '09/16/2021' '09/02/2021'
#  '07/01/2021' '03/16/2021' '06/01/2021' '07/23/2021' '03/24/2021'
#  '08/27/2021' '07/05/2021' '06/10/2021' '07/15/2021' '08/19/2021'
#  '03/26/2021' '05/24/2021' '08/03/2021' '04/16/2021' '05/31/2021'
#  '07/02/2021' '07/16/2021' '09/09/2021' '04/26/2021' '04/08/2021'
#  '04/13/2021' '07/09/2021' '05/11/2021' '06/16/2021' '04/05/2021'
#  '06/15/2021' '06/22/2021' '08/06/2021' '04/19/2021' '05/05/2021'
#  '06/09/2021' '05/14/2021' '08/31/2021' '07/06/2021' '07/20/2021'
#  '08/05/2021' '09/14/2021' '04/06/2021' '04/01/2021' '05/18/2021'
#  '05/28/2021' '04/20/2021' '07/13/2021' '04/21/2021' '06/14/2021'
#  '08/17/2021' '06/07/2021' '08/11/2021' '06/24/2021' '04/29/2021'
#  '03/10/2021' '05/04/2021' '08/09/2021' '06/17/2021' '06/29/2021'
#  '04/23/2021' '07/30/2021' '05/07/2021' '05/21/2021' '05/20/2021'
#  '03/15/2021' '08/04/2021' '07/07/2021' '03/04/2021' '06/02/2021'
#  '08/18/2021' '05/10/2021' '05/06/2021' '03/29/2021' '08/02/2021'
#  '04/09/2021' '06/04/2021' '03/31/2021' '07/08/2021' '07/22/2021'
#  '03/05/2021' '05/03/2021' '06/25/2021' '03/23/2021' '09/01/2021'
#  '05/26/2021' '04/22/2021' '04/15/2021' '04/27/2021' '05/27/2021'
#  '06/23/2021' '08/23/2021' '07/29/2021' '05/25/2021' '06/30/2021'
#  '03/12/2021' '08/13/2021' '03/19/2021' '03/17/2021' '07/26/2021'
#  '08/25/2021' '08/16/2021' '07/12/2021' '09/13/2021' '02/26/2021'
#  '06/03/2021' '04/14/2021' '05/17/2021' '09/06/2021' '05/19/2021'
#  '07/28/2021' '08/26/2021' '08/30/2021' '08/12/2021' '06/21/2021'
#  '03/18/2021' '01/29/2021' '07/21/2021' '04/28/2021' '03/25/2021'
#  '04/12/2021' '06/08/2021' '03/30/2021' '04/30/2021' '06/11/2021'
#  '04/07/2021' '05/13/2021' '08/20/2021' '08/24/2021' '08/10/2021'
#  '03/11/2021' '09/07/2021']
# There are 142
# Current date is 09/15/2021
# 	 0.665 sec
# 	 21.538 sec
# 	 1.278 sec
# Current date is 06/18/2021
# 	 1.666 sec
# 	 41.641 sec
# 	 1.235 sec
# Current date is 09/10/2021
# 	 1.685 sec
# 	 23.373 sec
# 	 0.768 sec
# Current date is 09/08/2021
# 	 2.520 sec
# 	 32.031 sec
# 	 0.784 sec
# Current date is 09/03/2021
# 	 0.967 sec
# 	 26.426 sec
# 	 0.484 sec
# Current date is 07/14/2021
# 	 1.121 sec
# 	 30.409 sec
# 	 0.617 sec
# Current date is 02/25/2021
# 	 0.053 sec
# 	 3.760 sec
# 	 3.705 sec
# Current date is 03/22/2021
# 	 0.050 sec
# 	 1.520 sec
# 	 1.649 sec
# Current date is 06/28/2021
# 	 0.997 sec
# 	 15.886 sec
# 	 0.397 sec
# Current date is 07/19/2021
# 	 3.020 sec
# 	 56.810 sec
# 	 1.548 sec
# Current date is 03/03/2021
# 	 0.067 sec
# 	 1.851 sec
# 	 3.871 sec
# Current date is 05/12/2021
# 	 0.083 sec
# 	 2.653 sec
# 	 3.420 sec
# Current date is 07/27/2021
# 	 2.019 sec
# 	 53.738 sec
# 	 1.002 sec
# Current date is 09/16/2021
# 	 0.595 sec
# 	 26.512 sec
# 	 1.130 sec
# Current date is 09/02/2021
# 	 1.126 sec
# 	 20.936 sec
# 	 0.406 sec
# Current date is 07/01/2021
# 	 0.920 sec
# 	 14.631 sec
# 	 0.322 sec
# Current date is 03/16/2021
# 	 0.065 sec
# 	 1.378 sec
# 	 1.683 sec
# Current date is 06/01/2021
# 	 0.117 sec
# 	 2.784 sec
# 	 0.593 sec
# Current date is 07/23/2021
# 	 0.996 sec
# 	 19.832 sec
# 	 0.355 sec
# Current date is 03/24/2021
# 	 0.065 sec
# 	 3.674 sec
# 	 2.365 sec
# Current date is 08/27/2021
# 	 2.280 sec
# 	 28.564 sec
# 	 0.870 sec
# Current date is 07/05/2021
# 	 0.128 sec
# 	 1.004 sec
# 	 0.089 sec
# Current date is 06/10/2021
# 	 0.692 sec
# 	 10.670 sec
# 	 0.541 sec
# Current date is 07/15/2021
# 	 1.525 sec
# 	 31.109 sec
# 	 0.611 sec
# Current date is 08/19/2021
# 	 1.867 sec
# 	 63.270 sec
# 	 0.992 sec
# Current date is 03/26/2021
# 	 0.065 sec
# 	 1.704 sec
# 	 2.323 sec
# Current date is 05/24/2021
# 	 0.076 sec
# 	 0.859 sec
# 	 0.865 sec
# Current date is 08/03/2021
# 	 2.148 sec
# 	 39.407 sec
# 	 1.011 sec
# Current date is 04/16/2021
# 	 0.055 sec
# 	 1.629 sec
# 	 1.104 sec
# Current date is 05/31/2021
# 	 0.041 sec
# 	 0.179 sec
# 	 0.143 sec
# Current date is 07/02/2021
# 	 0.665 sec
# 	 15.408 sec
# 	 0.331 sec
# Current date is 07/16/2021
# 	 1.479 sec
# 	 31.500 sec
# 	 0.766 sec
# Current date is 09/09/2021
# 	 1.350 sec
# 	 39.384 sec
# 	 0.874 sec
# Current date is 04/26/2021
# 	 0.052 sec
# 	 1.323 sec
# 	 1.279 sec
# Current date is 04/08/2021
# 	 0.049 sec
# 	 1.529 sec
# 	 1.242 sec
# Current date is 04/13/2021
# 	 0.055 sec
# 	 1.434 sec
# 	 1.382 sec
# Current date is 07/09/2021
# 	 0.977 sec
# 	 26.606 sec
# 	 0.310 sec
# Current date is 05/11/2021
# 	 0.075 sec
# 	 2.677 sec
# 	 2.584 sec
# Current date is 06/16/2021
# 	 2.385 sec
# 	 50.283 sec
# 	 2.750 sec
# Current date is 04/05/2021
# 	 0.058 sec
# 	 1.691 sec
# 	 1.030 sec
# Current date is 06/15/2021
# 	 1.206 sec
# 	 20.196 sec
# 	 0.380 sec
# Current date is 06/22/2021
# 	 1.042 sec
# 	 26.258 sec
# 	 0.400 sec
# Current date is 08/06/2021
# 	 1.008 sec
# 	 23.530 sec
# 	 0.510 sec
# Current date is 04/19/2021
# 	 0.062 sec
# 	 1.596 sec
# 	 1.739 sec
# Current date is 05/05/2021
# 	 0.056 sec
# 	 1.884 sec
# 	 1.882 sec
# Current date is 06/09/2021
# 	 0.360 sec
# 	 5.598 sec
# 	 0.737 sec
# Current date is 05/14/2021
# 	 0.077 sec
# 	 1.590 sec
# 	 1.244 sec
# Current date is 08/31/2021
# 	 1.329 sec
# 	 33.831 sec
# 	 0.610 sec
# Current date is 07/06/2021
# 	 1.189 sec
# 	 31.872 sec
# 	 0.489 sec
# Current date is 07/20/2021
# 	 1.944 sec
# 	 27.581 sec
# 	 0.577 sec
# Current date is 08/05/2021
# 	 0.707 sec
# 	 14.159 sec
# 	 0.343 sec
# Current date is 09/14/2021
# 	 1.091 sec
# 	 24.713 sec
# 	 1.674 sec
# Current date is 04/06/2021
# 	 0.072 sec
# 	 1.455 sec
# 	 1.405 sec
# Current date is 04/01/2021
# 	 0.057 sec
# 	 1.948 sec
# 	 1.561 sec
# Current date is 05/18/2021
# 	 0.062 sec
# 	 2.091 sec
# 	 1.621 sec
# Current date is 05/28/2021
# 	 0.058 sec
# 	 0.938 sec
# 	 0.830 sec
# Current date is 04/20/2021
# 	 0.067 sec
# 	 2.765 sec
# 	 2.092 sec
# Current date is 07/13/2021
# 	 1.980 sec
# 	 21.325 sec
# 	 0.620 sec
# Current date is 04/21/2021
# 	 0.058 sec
# 	 1.539 sec
# 	 1.288 sec
# Current date is 06/14/2021
# 	 1.260 sec
# 	 25.879 sec
# 	 0.471 sec
# Current date is 08/17/2021
# 	 2.095 sec
# 	 50.613 sec
# 	 0.754 sec
# Current date is 06/07/2021
# 	 0.134 sec
# 	 3.679 sec
# 	 0.558 sec
# Current date is 08/11/2021
# 	 0.857 sec
# 	 25.264 sec
# 	 0.388 sec
# Current date is 06/24/2021
# 	 0.797 sec
# 	 19.064 sec
# 	 0.319 sec
# Current date is 04/29/2021
# 	 0.062 sec
# 	 2.250 sec
# 	 2.531 sec
# Current date is 03/10/2021
# 	 0.051 sec
# 	 2.372 sec
# 	 1.511 sec
# Current date is 05/04/2021
# 	 0.074 sec
# 	 2.133 sec
# 	 2.264 sec
# Current date is 08/09/2021
# 	 0.715 sec
# 	 13.263 sec
# 	 0.326 sec
# Current date is 06/17/2021
# 	 2.129 sec
# 	 36.197 sec
# 	 0.787 sec
# Current date is 06/29/2021
# 	 0.775 sec
# 	 14.707 sec
# 	 0.287 sec
# Current date is 04/23/2021
# 	 0.057 sec
# 	 1.012 sec
# 	 0.940 sec
# Current date is 07/30/2021
# 	 1.040 sec
# 	 27.546 sec
# 	 0.617 sec
# Current date is 05/07/2021
# 	 0.076 sec
# 	 1.762 sec
# 	 1.793 sec
# Current date is 05/21/2021
# 	 0.064 sec
# 	 1.409 sec
# 	 1.751 sec
# Current date is 05/20/2021
# 	 0.067 sec
# 	 1.893 sec
# 	 1.374 sec
# Current date is 03/15/2021
# 	 0.052 sec
# 	 0.861 sec
# 	 0.622 sec
# Current date is 08/04/2021
# 	 0.963 sec
# 	 21.491 sec
# 	 0.561 sec
# Current date is 07/07/2021
# 	 1.957 sec
# 	 31.784 sec
# 	 0.791 sec
# Current date is 03/04/2021
# 	 0.054 sec
# 	 4.779 sec
# 	 4.005 sec
# Current date is 06/02/2021
# 	 0.150 sec
# 	 1.726 sec
# 	 0.828 sec
# Current date is 08/18/2021
# 	 1.768 sec
# 	 39.437 sec
# 	 1.417 sec
# Current date is 05/10/2021
# 	 0.075 sec
# 	 1.995 sec
# 	 1.860 sec
# Current date is 05/06/2021
# 	 0.071 sec
# 	 2.380 sec
# 	 2.404 sec
# Current date is 03/29/2021
# 	 0.064 sec
# 	 2.723 sec
# 	 2.847 sec
# Current date is 08/02/2021
# 	 1.102 sec
# 	 21.355 sec
# 	 0.913 sec
# Current date is 04/09/2021
# 	 0.052 sec
# 	 1.359 sec
# 	 0.870 sec
# Current date is 06/04/2021
# 	 0.104 sec
# 	 1.139 sec
# 	 0.392 sec
# Current date is 03/31/2021
# 	 0.060 sec
# 	 2.258 sec
# 	 1.230 sec
# Current date is 07/08/2021
# 	 2.290 sec
# 	 36.019 sec
# 	 1.416 sec
# Current date is 07/22/2021
# 	 0.905 sec
# 	 41.453 sec
# 	 0.547 sec
# Current date is 03/05/2021
# 	 0.047 sec
# 	 3.686 sec
# 	 4.718 sec
# Current date is 05/03/2021
# 	 0.061 sec
# 	 1.672 sec
# 	 1.629 sec
# Current date is 06/25/2021
# 	 0.731 sec
# 	 20.342 sec
# 	 0.269 sec
# Current date is 03/23/2021
# 	 0.063 sec
# 	 1.759 sec
# 	 1.987 sec
# Current date is 09/01/2021
# 	 0.923 sec
# 	 16.136 sec
# 	 0.452 sec
# Current date is 05/26/2021
# 	 0.057 sec
# 	 1.429 sec
# 	 1.162 sec
# Current date is 04/22/2021
# 	 0.061 sec
# 	 1.968 sec
# 	 1.775 sec
# Current date is 04/15/2021
# 	 0.055 sec
# 	 1.484 sec
# 	 1.240 sec
# Current date is 04/27/2021
# 	 0.053 sec
# 	 1.208 sec
# 	 1.343 sec
# Current date is 05/27/2021
# 	 0.062 sec
# 	 1.133 sec
# 	 1.081 sec
# Current date is 06/23/2021
# 	 1.179 sec
# 	 22.504 sec
# 	 0.356 sec
# Current date is 08/23/2021
# 	 0.857 sec
# 	 16.753 sec
# 	 0.345 sec
# Current date is 07/29/2021
# 	 0.814 sec
# 	 21.459 sec
# 	 0.452 sec
# Current date is 05/25/2021
# 	 0.074 sec
# 	 1.988 sec
# 	 1.214 sec
# Current date is 06/30/2021
# 	 0.845 sec
# 	 13.699 sec
# 	 0.397 sec
# Current date is 03/12/2021
# 	 0.048 sec
# 	 0.707 sec
# 	 0.685 sec
# Current date is 08/13/2021
# 	 0.654 sec
# 	 12.248 sec
# 	 0.312 sec
# Current date is 03/19/2021
# 	 0.058 sec
# 	 2.880 sec
# 	 2.656 sec
# Current date is 03/17/2021
# 	 0.055 sec
# 	 1.927 sec
# 	 1.891 sec
# Current date is 07/26/2021
# 	 0.785 sec
# 	 25.790 sec
# 	 0.444 sec
# Current date is 08/25/2021
# 	 0.678 sec
# 	 14.855 sec
# 	 0.292 sec
# Current date is 08/16/2021
# 	 1.105 sec
# 	 23.192 sec
# 	 0.459 sec
# Current date is 07/12/2021
# 	 1.092 sec
# 	 25.895 sec
# 	 0.462 sec
# Current date is 09/13/2021
# 	 1.406 sec
# 	 45.061 sec
# 	 1.863 sec
# Current date is 02/26/2021
# 	 0.055 sec
# 	 3.603 sec
# 	 3.582 sec
# Current date is 06/03/2021
# 	 0.139 sec
# 	 3.351 sec
# 	 1.080 sec
# Current date is 04/14/2021
# 	 0.061 sec
# 	 2.661 sec
# 	 2.559 sec
# Current date is 05/17/2021
# 	 0.059 sec
# 	 2.943 sec
# 	 3.071 sec
# Current date is 09/06/2021
# 	 0.133 sec
# 	 1.249 sec
# 	 0.079 sec
# Current date is 05/19/2021
# 	 0.081 sec
# 	 3.504 sec
# 	 3.408 sec
# Current date is 07/28/2021
# 	 1.632 sec
# 	 34.420 sec
# 	 0.993 sec
# Current date is 08/26/2021
# 	 1.517 sec
# 	 43.203 sec
# 	 0.754 sec
# Current date is 08/30/2021
# 	 0.802 sec
# 	 22.243 sec
# 	 0.317 sec
# Current date is 08/12/2021
# 	 0.756 sec
# 	 19.277 sec
# 	 0.389 sec
# Current date is 06/21/2021
# 	 1.232 sec
# 	 25.015 sec
# 	 0.528 sec
# Current date is 03/18/2021
# 	 0.056 sec
# 	 2.156 sec
# 	 2.419 sec
# Current date is 01/29/2021
# 	 0.061 sec
# 	 1.727 sec
# 	 2.910 sec
# Current date is 07/21/2021
# 	 0.909 sec
# 	 22.885 sec
# 	 0.610 sec
# Current date is 04/28/2021
# 	 0.057 sec
# 	 1.311 sec
# 	 0.824 sec
# Current date is 03/25/2021
# 	 0.070 sec
# 	 3.399 sec
# 	 2.348 sec
# Current date is 04/12/2021
# 	 0.053 sec
# 	 1.585 sec
# 	 1.209 sec
# Current date is 06/08/2021
# 	 0.199 sec
# 	 5.414 sec
# 	 0.964 sec
# Current date is 03/30/2021
# 	 0.060 sec
# 	 2.191 sec
# 	 2.213 sec
# Current date is 04/30/2021
# 	 0.060 sec
# 	 2.377 sec
# 	 1.596 sec
# Current date is 06/11/2021
# 	 0.806 sec
# 	 16.735 sec
# 	 0.443 sec
# Current date is 04/07/2021
# 	 0.059 sec
# 	 1.390 sec
# 	 1.321 sec
# Current date is 05/13/2021
# 	 0.092 sec
# 	 3.095 sec
# 	 2.425 sec
# Current date is 08/20/2021
# 	 1.476 sec
# 	 21.925 sec
# 	 0.503 sec
# Current date is 08/24/2021
# 	 0.705 sec
# 	 16.170 sec
# 	 0.303 sec
# Current date is 08/10/2021
# 	 0.977 sec
# 	 20.166 sec
# 	 0.529 sec
# Current date is 03/11/2021
# 	 0.054 sec
# 	 0.678 sec
# 	 0.667 sec
# Current date is 09/07/2021
# 	 1.078 sec
# 	 20.575 sec
# 	 0.437 sec
# 2021.75	09/10/2021  (2575.219 s)
# The dates are: ['09/15/2021' '10/12/2021' '11/01/2021' '09/13/2021' '09/21/2021'
#  '11/12/2021' '10/01/2021' '11/04/2021' '09/20/2021' '12/10/2021'
#  '12/13/2021' '11/16/2021' '11/10/2021' '12/15/2021' '09/22/2021'
#  '12/16/2021' '12/09/2021' '09/28/2021' '11/09/2021' '11/11/2021'
#  '11/02/2021' '10/11/2021' '10/22/2021' '10/21/2021' '11/05/2021'
#  '12/02/2021' '09/27/2021' '11/22/2021' '11/24/2021' '09/24/2021'
#  '09/16/2021' '09/30/2021' '10/25/2021' '10/15/2021' '10/06/2021'
#  '10/18/2021' '09/23/2021' '11/17/2021' '12/01/2021' '11/19/2021'
#  '10/07/2021' '12/03/2021' '10/27/2021' '09/14/2021' '11/29/2021'
#  '10/29/2021' '10/26/2021' '11/23/2021' '09/29/2021' '10/19/2021'
#  '10/14/2021' '11/15/2021' '11/18/2021' '11/03/2021' '12/07/2021'
#  '10/04/2021' '10/28/2021' '11/25/2021' '09/17/2021' '11/30/2021'
#  '10/08/2021' '10/20/2021' '11/26/2021' '11/08/2021' '12/14/2021'
#  '10/13/2021' '12/08/2021' '12/06/2021' '10/05/2021']
# There are 69
# Current date is 09/15/2021
# 	 1.747 sec
# 	 30.983 sec
# 	 0.753 sec
# Current date is 10/12/2021
# 	 2.557 sec
# 	 72.585 sec
# 	 1.776 sec
# Current date is 11/01/2021
# 	 1.141 sec
# 	 27.276 sec
# 	 0.779 sec
# Current date is 09/13/2021
# 	 1.949 sec
# 	 51.506 sec
# 	 1.679 sec
# Current date is 09/21/2021
# 	 3.071 sec
# 	 62.217 sec
# 	 1.179 sec
# Current date is 11/12/2021
# 	 1.020 sec
# 	 21.030 sec
# 	 0.480 sec
# Current date is 10/01/2021
# 	 2.284 sec
# 	 71.752 sec
# 	 1.363 sec
# Current date is 11/04/2021
# 	 1.075 sec
# 	 31.428 sec
# 	 0.682 sec
# Current date is 09/20/2021
# 	 3.119 sec
# 	 53.902 sec
# 	 1.727 sec
# Current date is 12/10/2021
# 	 1.246 sec
# 	 28.772 sec
# 	 1.051 sec
# Current date is 12/13/2021
# 	 1.610 sec
# 	 36.243 sec
# 	 1.673 sec
# Current date is 11/16/2021
# 	 1.415 sec
# 	 21.579 sec
# 	 0.555 sec
# Current date is 11/10/2021
# 	 1.701 sec
# 	 53.365 sec
# 	 0.962 sec
# Current date is 12/15/2021
# 	 1.867 sec
# 	 34.133 sec
# 	 7.224 sec
# Current date is 09/22/2021
# 	 2.376 sec
# 	 46.391 sec
# 	 3.882 sec
# Current date is 12/16/2021
# 	 0.892 sec
# 	 25.652 sec
# 	 2.916 sec
# Current date is 12/09/2021
# 	 2.793 sec
# 	 47.447 sec
# 	 1.345 sec
# Current date is 09/28/2021
# 	 2.931 sec
# 	 66.813 sec
# 	 2.124 sec
# Current date is 11/09/2021
# 	 1.803 sec
# 	 49.444 sec
# 	 1.514 sec
# Current date is 11/11/2021
# 	 1.176 sec
# 	 27.423 sec
# 	 0.628 sec
# Current date is 11/02/2021
# 	 1.233 sec
# 	 35.118 sec
# 	 0.417 sec
# Current date is 10/11/2021
# 	 1.986 sec
# 	 45.876 sec
# 	 0.823 sec
# Current date is 10/22/2021
# 	 1.810 sec
# 	 33.010 sec
# 	 0.896 sec
# Current date is 10/21/2021
# 	 0.852 sec
# 	 21.473 sec
# 	 0.375 sec
# Current date is 11/05/2021
# 	 1.288 sec
# 	 36.977 sec
# 	 0.824 sec
# Current date is 12/02/2021
# 	 3.380 sec
# 	 104.762 sec
# 	 3.350 sec
# Current date is 09/27/2021
# 	 1.539 sec
# 	 38.577 sec
# 	 0.831 sec
# Current date is 11/22/2021
# 	 1.536 sec
# 	 31.092 sec
# 	 0.999 sec
# Current date is 11/24/2021
# 	 1.682 sec
# 	 48.393 sec
# 	 1.153 sec
# Current date is 09/24/2021
# 	 1.413 sec
# 	 25.871 sec
# 	 0.753 sec
# Current date is 09/16/2021
# 	 1.504 sec
# 	 30.660 sec
# 	 0.827 sec
# Current date is 09/30/2021
# 	 2.389 sec
# 	 60.123 sec
# 	 1.760 sec
# Current date is 10/25/2021
# 	 0.926 sec
# 	 24.877 sec
# 	 0.650 sec
# Current date is 10/15/2021
# 	 1.321 sec
# 	 25.885 sec
# 	 0.609 sec
# Current date is 10/06/2021
# 	 3.268 sec
# 	 68.705 sec
# 	 1.517 sec
# Current date is 10/18/2021
# 	 0.961 sec
# 	 18.631 sec
# 	 0.626 sec
# Current date is 09/23/2021
# 	 1.245 sec
# 	 30.786 sec
# 	 0.547 sec
# Current date is 11/17/2021
# 	 1.421 sec
# 	 29.219 sec
# 	 0.710 sec
# Current date is 12/01/2021
# 	 5.940 sec
# 	 90.970 sec
# 	 2.790 sec
# Current date is 11/19/2021
# 	 1.559 sec
# 	 33.993 sec
# 	 0.670 sec
# Current date is 10/07/2021
# 	 1.254 sec
# 	 36.098 sec
# 	 0.716 sec
# Current date is 12/03/2021
# 	 4.720 sec
# 	 69.690 sec
# 	 3.174 sec
# Current date is 10/27/2021
# 	 1.625 sec
# 	 28.976 sec
# 	 0.747 sec
# Current date is 09/14/2021
# 	 1.775 sec
# 	 32.378 sec
# 	 0.800 sec
# Current date is 11/29/2021
# 	 1.879 sec
# 	 30.755 sec
# 	 2.101 sec
# Current date is 10/29/2021
# 	 1.125 sec
# 	 20.818 sec
# 	 0.723 sec
# Current date is 10/26/2021
# 	 1.706 sec
# 	 39.136 sec
# 	 0.847 sec
# Current date is 11/23/2021
# 	 2.870 sec
# 	 80.695 sec
# 	 1.983 sec
# Current date is 09/29/2021
# 	 2.407 sec
# 	 49.685 sec
# 	 1.297 sec
# Current date is 10/19/2021
# 	 1.907 sec
# 	 23.922 sec
# 	 0.698 sec
# Current date is 10/14/2021
# 	 1.134 sec
# 	 14.455 sec
# 	 0.612 sec
# Current date is 11/15/2021
# 	 1.200 sec
# 	 27.637 sec
# 	 0.761 sec
# Current date is 11/18/2021
# 	 1.813 sec
# 	 34.819 sec
# 	 0.957 sec
# Current date is 11/03/2021
# 	 1.939 sec
# 	 38.466 sec
# 	 1.467 sec
# Current date is 12/07/2021
# 	 1.592 sec
# 	 35.444 sec
# 	 0.994 sec
# Current date is 10/04/2021
# 	 2.407 sec
# 	 58.407 sec
# 	 1.891 sec
# Current date is 10/28/2021
# 	 1.133 sec
# 	 31.719 sec
# 	 0.819 sec
# Current date is 11/25/2021
# 	 0.142 sec
# 	 0.973 sec
# 	 0.137 sec
# Current date is 09/17/2021
# 	 2.256 sec
# 	 48.161 sec
# 	 1.042 sec
# Current date is 11/30/2021
# 	 4.195 sec
# 	 71.463 sec
# 	 3.018 sec
# Current date is 10/08/2021
# 	 1.854 sec
# 	 46.228 sec
# 	 1.143 sec
# Current date is 10/20/2021
# 	 1.261 sec
# 	 16.378 sec
# 	 0.444 sec
# Current date is 11/26/2021
# 	 2.689 sec
# 	 39.680 sec
# 	 2.535 sec
# Current date is 11/08/2021
# 	 1.257 sec
# 	 25.946 sec
# 	 0.555 sec
# Current date is 12/14/2021
# 	 1.373 sec
# 	 49.836 sec
# 	 2.666 sec
# Current date is 10/13/2021
# 	 2.266 sec
# 	 28.228 sec
# 	 1.337 sec
# Current date is 12/08/2021
# 	 2.088 sec
# 	 32.508 sec
# 	 1.262 sec
# Current date is 12/06/2021
# 	 4.796 sec
# 	 62.553 sec
# 	 3.871 sec
# Current date is 10/05/2021
# 	 1.643 sec
# 	 41.900 sec
# 	 0.857 sec
# 2022.0	12/10/2021  (3381.182 s)
# The dates are: ['02/24/2022' '02/03/2022' '03/02/2022' '03/04/2022' '12/13/2021'
#  '01/04/2022' '03/11/2022' '12/20/2021' '12/15/2021' '02/02/2022'
#  '03/14/2022' '01/28/2022' '01/06/2022' '12/16/2021' '01/14/2022'
#  '03/03/2022' '12/23/2021' '12/17/2021' '12/28/2021' '01/17/2022'
#  '01/07/2022' '02/23/2022' '01/05/2022' '02/21/2022' '02/11/2022'
#  '02/16/2022' '02/10/2022' '01/27/2022' '02/04/2022' '12/31/2021'
#  '01/25/2022' '01/12/2022' '01/03/2022' '12/30/2021' '01/19/2022'
#  '02/15/2022' '03/01/2022' '01/21/2022' '01/13/2022' '12/27/2021'
#  '02/18/2022' '03/10/2022' '03/15/2022' '02/22/2022' '12/21/2021'
#  '03/07/2022' '02/25/2022' '03/16/2022' '03/08/2022' '03/18/2022'
#  '02/09/2022' '12/22/2021' '01/31/2022' '03/09/2022' '01/10/2022'
#  '02/07/2022' '02/17/2022' '02/08/2022' '02/14/2022' '02/28/2022'
#  '01/24/2022' '03/17/2022' '01/20/2022' '01/11/2022' '01/26/2022'
#  '01/18/2022' '12/14/2021' '02/01/2022' '12/29/2021']
# There are 69
# Current date is 02/24/2022
# 	 6.457 sec
# 	 80.982 sec
# 	 5.200 sec
# Current date is 02/03/2022
# 	 3.560 sec
# 	 55.834 sec
# 	 3.539 sec
# Current date is 03/02/2022
# 	 3.633 sec
# 	 34.676 sec
# 	 3.521 sec
# Current date is 03/04/2022
# 	 4.222 sec
# 	 55.818 sec
# 	 3.204 sec
# Current date is 12/13/2021
# 	 2.031 sec
# 	 54.564 sec
# 	 2.865 sec
# Current date is 01/04/2022
# 	 2.304 sec
# 	 40.017 sec
# 	 0.965 sec
# Current date is 03/11/2022
# 	 2.049 sec
# 	 22.033 sec
# 	 2.568 sec
# Current date is 12/20/2021
# 	 2.668 sec
# 	 53.183 sec
# 	 3.959 sec
# Current date is 12/15/2021
# 	 3.483 sec
# 	 49.175 sec
# 	 5.259 sec
# Current date is 02/02/2022
# 	 2.616 sec
# 	 48.115 sec
# 	 3.270 sec
# Current date is 03/14/2022
# 	 1.284 sec
# 	 26.710 sec
# 	 2.152 sec
# Current date is 01/28/2022
# 	 3.370 sec
# 	 72.139 sec
# 	 4.888 sec
# Current date is 01/06/2022
# 	 2.839 sec
# 	 67.578 sec
# 	 3.759 sec
# Current date is 12/16/2021
# 	 4.430 sec
# 	 64.730 sec
# 	 3.203 sec
# Current date is 01/14/2022
# 	 3.601 sec
# 	 41.339 sec
# 	 2.212 sec
# Current date is 03/03/2022
# 	 3.401 sec
# 	 49.302 sec
# 	 4.141 sec
# Current date is 12/23/2021
# 	 0.997 sec
# 	 18.692 sec
# 	 0.551 sec
# Current date is 12/17/2021
# 	 2.996 sec
# 	 67.318 sec
# 	 3.068 sec
# Current date is 12/28/2021
# 	 1.381 sec
# 	 30.686 sec
# 	 1.431 sec
# Current date is 01/17/2022
# 	 0.207 sec
# 	 1.380 sec
# 	 0.207 sec
# Current date is 01/07/2022
# 	 1.989 sec
# 	 36.834 sec
# 	 1.574 sec
# Current date is 02/23/2022
# 	 3.935 sec
# 	 51.734 sec
# 	 2.152 sec
# Current date is 01/05/2022
# 	 2.661 sec
# 	 62.255 sec
# 	 3.356 sec
# Current date is 02/21/2022
# 	 0.643 sec
# 	 4.650 sec
# 	 0.727 sec
# Current date is 02/11/2022
# 	 4.264 sec
# 	 85.125 sec
# 	 10.287 sec
# Current date is 02/16/2022
# 	 3.235 sec
# 	 43.152 sec
# 	 3.746 sec
# Current date is 02/10/2022
# 	 3.847 sec
# 	 70.804 sec
# 	 3.793 sec
# Current date is 01/27/2022
# 	 7.865 sec
# 	 81.185 sec
# 	 5.934 sec
# Current date is 02/04/2022
# 	 2.691 sec
# 	 55.553 sec
# 	 3.474 sec
# Current date is 12/31/2021
# 	 1.029 sec
# 	 22.289 sec
# 	 1.092 sec
# Current date is 01/25/2022
# 	 5.245 sec
# 	 77.399 sec
# 	 7.519 sec
# Current date is 01/12/2022
# 	 2.722 sec
# 	 33.451 sec
# 	 1.359 sec
# Current date is 01/03/2022
# 	 2.681 sec
# 	 37.277 sec
# 	 1.989 sec
# Current date is 12/30/2021
# 	 0.883 sec
# 	 17.079 sec
# 	 0.701 sec
# Current date is 01/19/2022
# 	 2.441 sec
# 	 50.163 sec
# 	 1.825 sec
# Current date is 02/15/2022
# 	 2.139 sec
# 	 27.841 sec
# 	 1.752 sec
# Current date is 03/01/2022
# 	 2.910 sec
# 	 54.636 sec
# 	 4.075 sec
# Current date is 01/21/2022
# 	 4.445 sec
# 	 71.686 sec
# 	 4.977 sec
# Current date is 01/13/2022
# 	 2.605 sec
# 	 49.515 sec
# 	 2.065 sec
# Current date is 12/27/2021
# 	 1.014 sec
# 	 17.241 sec
# 	 0.673 sec
# Current date is 02/18/2022
# 	 3.662 sec
# 	 48.563 sec
# 	 2.801 sec
# Current date is 03/10/2022
# 	 3.779 sec
# 	 42.507 sec
# 	 3.213 sec
# Current date is 03/15/2022
# 	 1.380 sec
# 	 31.574 sec
# 	 2.134 sec
# Current date is 02/22/2022
# 	 3.153 sec
# 	 65.883 sec
# 	 3.650 sec
# Current date is 12/21/2021
# 	 2.462 sec
# 	 51.419 sec
# 	 1.185 sec
# Current date is 03/07/2022
# 	 2.768 sec
# 	 52.859 sec
# 	 3.426 sec
# Current date is 02/25/2022
# 	 3.672 sec
# 	 50.814 sec
# 	 3.222 sec
# Current date is 03/16/2022
# 	 1.322 sec
# 	 34.536 sec
# 	 3.937 sec
# Current date is 03/08/2022
# 	 5.031 sec
# 	 76.519 sec
# 	 5.581 sec
# Current date is 03/18/2022
# 	 0.001 sec
# 	 0.001 sec
# 	 0.001 sec
# Current date is 02/09/2022
# 	 2.823 sec
# 	 33.542 sec
# 	 1.231 sec
# Current date is 12/22/2021
# 	 1.397 sec
# 	 25.283 sec
# 	 1.133 sec
# Current date is 01/31/2022
# 	 2.362 sec
# 	 32.706 sec
# 	 2.398 sec
# Current date is 03/09/2022
# 	 3.029 sec
# 	 37.105 sec
# 	 2.673 sec
# Current date is 01/10/2022
# 	 3.055 sec
# 	 50.986 sec
# 	 2.536 sec
# Current date is 02/07/2022
# 	 2.849 sec
# 	 40.125 sec
# 	 1.793 sec
# Current date is 02/17/2022
# 	 2.138 sec
# 	 26.726 sec
# 	 2.117 sec
# Current date is 02/08/2022
# 	 2.334 sec
# 	 43.283 sec
# 	 2.261 sec
# Current date is 02/14/2022
# 	 4.816 sec
# 	 90.162 sec
# 	 4.139 sec
# Current date is 02/28/2022
# 	 3.770 sec
# 	 48.292 sec
# 	 4.307 sec
# Current date is 01/24/2022
# 	 6.042 sec
# 	 98.804 sec
# 	 8.336 sec
# Current date is 03/17/2022
# 	 0.882 sec
# 	 21.527 sec
# 	 2.264 sec
# Current date is 01/20/2022
# 	 2.643 sec
# 	 37.306 sec
# 	 2.161 sec
# Current date is 01/11/2022
# 	 2.418 sec
# 	 35.317 sec
# 	 2.790 sec
# Current date is 01/26/2022
# 	 6.652 sec
# 	 79.994 sec
# 	 11.099 sec
# Current date is 01/18/2022
# 	 2.717 sec
# 	 36.870 sec
# 	 1.803 sec
# Current date is 12/14/2021
# 	 2.400 sec
# 	 73.988 sec
# 	 1.892 sec
# Current date is 02/01/2022
# 	 3.356 sec
# 	 44.672 sec
# 	 2.391 sec
# Current date is 12/29/2021
# 	 1.207 sec
# 	 32.958 sec
# 	 0.753 sec
# 2022.25	03/11/2022  (4121.823 s)
